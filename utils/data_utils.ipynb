# %%
# pobranie złotych danych 

import pandas as pd

URL = "https://freegoldapi.com/data/latest.csv"  

df = pd.read_csv(URL)

df["date"] = pd.to_datetime(df["date"], errors="coerce")
df = df.dropna(subset=["date"])

df["yearmonth"] = df["date"].dt.to_period("M").astype(str)

monthly = (
    df.groupby("yearmonth", as_index=False)["price"]
      .mean()
      .rename(columns={"yearmonth": "date", "price": "price_usd_per_troy_oz"})
)

monthly = monthly[(monthly["date"] >= "2005-01") & (monthly["date"] <= "2025-12")]

monthly.to_csv("gold_price_monthly_USD_2005_2025.csv", index=False)
print("Zapisano: gold_price_monthly_USD_2005_2025.csv")
# Out:
# Zapisano: gold_price_monthly_USD_2005_2025.csv
# /tmp/ipykernel_343827/3219423956.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["date"] = pd.to_datetime(df["date"], errors="coerce")

# %%
# pobranie srebrnych danych
import pandas as pd

URL = "https://stooq.pl/q/d/l/?s=xagusd&i=d"
df = pd.read_csv(URL)

df["date"] = pd.to_datetime(df["Data"], errors="coerce")
df["price"] = pd.to_numeric(df["Zamkniecie"], errors="coerce")
df = df.dropna(subset=["date","price"])

df["yearmonth"] = df["date"].dt.to_period("M").astype(str)

monthly = (
    df.groupby("yearmonth", as_index=False)["price"]
      .mean().round(3)
      .rename(columns={"yearmonth": "date", "price": "price_usd_per_troy_oz"})
)

monthly = monthly[(monthly["date"] >= "2005-01") & (monthly["date"] <= "2025-12")]

monthly.to_csv('silver_price_monthly_USD_2005_2025.csv', index=False)
print('Zapisano: silver_price_monthly_USD_2005_2025.csv')

# %%
# zmiana jednostek dla danych dotyczących miedzi
# Dane zostały pobrane w postaci pliku csv ze strony https://fred.stlouisfed.org/ 
# dla okresu styczeń 2005 - czerwiec 2025
# dokładny link: https://fred.stlouisfed.org/series/PCOPPUSDM?fbclid=IwY2xjawPPM3tleHRuA2FlbQIxMQBzcnRjBmFwcF9pZAEwAAEebYVGUyCp7A3NnTSakLK8pHg7Ve4-huL10rHgFiYiqz7JdvIhqkPzdAalOjE_aem_rmkYr7B9_qqm-IaPWxiB1g

import pandas as pd

df = pd.read_csv(r"..\data\copper_price_monthly_USD_per_metric_ton_2005_2025.csv")

df["observation_date"] = pd.to_datetime(df["observation_date"], errors="coerce")

df["date"] = df["observation_date"].dt.to_period("M").astype(str)

# PRZELICZENIE JEDNOSTEK (Tona -> Uncja)
# 1 Tona Metryczna = 32150.746568628 Uncji Trojańskich
conversion_factor = 32150.746568628
df["price_usd_per_troy_oz"] = df["PCOPPUSDM"] / conversion_factor

final_df = df[["date", "price_usd_per_troy_oz"]].copy()
final_df["price_usd_per_troy_oz"] = final_df["price_usd_per_troy_oz"].round(4)

output_filename = "copper_price_monthly_USD_2005_2025.csv"
final_df.to_csv(r"..\data\copper_price_monthly_USD_2005_2025.csv", index=False)

print(f"Zapisano plik: {output_filename}")
# Out:
# Zapisano plik: copper_price_monthly_USD_2005_2025.csv
